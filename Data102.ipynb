# %% [markdown]
# <a href="https://colab.research.google.com/github/tonpiplaifa/KKU_data_mining/blob/master/Data102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os

# %%
import pandas as pd

# %%
base_path = '/content/drive/My Drive/DWDM_material'

# %%
data = pd.read_csv(os.path.join(base_path,'test.csv'))

# %%
data.head()
# Out:
#    Unnamed: 0        x        y
# 0           0  55.3846  97.1795
# 1           1  51.5385  96.0256
# 2           2  46.1538  94.4872
# 3           3  42.8205  91.4103
# 4           4  40.7692  88.3333

# %%
data.describe()
# Out:
#        Unnamed: 0           x           y
# count  142.000000  142.000000  142.000000
# mean    70.500000   54.263273   47.832253
# std     41.135953   16.765142   26.935403
# min      0.000000   22.307700    2.948700
# 25%     35.250000   44.102600   25.288450
# 50%     70.500000   53.333300   46.025600
# 75%    105.750000   64.743600   68.525675
# max    141.000000   98.205100   99.487200

# %% [markdown]
# ## Box plot

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(data['x'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f33482f96d8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f3348287128>,
#   <matplotlib.lines.Line2D at 0x7f33482874a8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3348287ba8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3348287828>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f33482f99e8>,
#   <matplotlib.lines.Line2D at 0x7f33482f9d68>]}

# %%
plt.boxplot(data['x'], vert=False, whis=1.2)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f3348312f60>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f334831f9b0>,
#   <matplotlib.lines.Line2D at 0x7f334831fd30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3348328470>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f33483280f0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f334831f2b0>,
#   <matplotlib.lines.Line2D at 0x7f334831f630>]}

# %%
oput = plt.boxplot(data['x'], vert=False, whis=1.2)

# %%
oput['fliers'][0].get_xdata()
# Out:
# array([93.3333, 95.3846, 98.2051, 91.2821])

# %%
oput['whiskers'][0].get_xdata()
# Out:
# array([44.1026, 22.3077])

# %%
oput['whiskers'][1].get_xdata()
# Out:
# array([64.7436, 89.4872])

# %% [markdown]
# ## Scatter plot

# %%
plt.scatter(data['x'],data['y'])

# %%
plt.scatter(data['x'],data['y'],s=25)

# %%
plt.scatter(data['x'],data['y'],s=data['y'])

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='k')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='m')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='c')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='y')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='#5d5df2',marker = '*')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='#5d5df2',marker = '*',alpha = 0.4)
plt.scatter([66,42,55],[20,14,80],s=250,alpha=0.6)

# %% [markdown]
# ## HW4 วาดปีกกลับนอให้ไดโนเสาร์

# %%
plt.scatter(data['x'],data['y'],s=100 ,c='#5d5df2',marker = '*')
plt.scatter([31,29,26,24,23,23,23,23,23],[80,83,87,89,90,72,77,83,86],s=100,c='r',marker = '*')
plt.scatter([80,80,85,90,91,92,93,94,95,96,97,95,96,97,95,92,89,82,84,85],[63,69,80,44,48,53,57,60,63,66,69,80,77,73,80,79,80,75,78,80],s=100,c='c',marker = '*')

# %% [markdown]
# ## Plot

# %%
plt.plot(data['x'],data['y'])

# %%
plt.plot(data['x'],data['y'],'ro-')

# %%
plt.plot(data['x'],data['y'],'ro-')
plt.plot(data['x'][0],data['y'][0],'co-')

# %%
plt.plot(data['x'],data['y'],'ro-')
plt.scatter(data['x'][0],data['y'][0],s=200,c='k')

# %%
plt.plot(data['x'],data['y'],'r-')
plt.scatter(data['x'],data['y'],s=range(10,len(data['x'])+10))

# %%
plt.plot(data['x'],data['y'],'r-')
plt.scatter(data['x'],data['y'],s=range(len(data['x'])))

# %%
plt.scatter(data['x'],data['y'],s=250,c=[[0.2,0.1,0.4,0.5]])

# %%
color_list = []
for i in range(len(data['x'])):
  color_list.append([0.2,0.4,i/255,0.5])
color_list
# Out:
# [[0.2, 0.4, 0.0, 0.5],
#  [0.2, 0.4, 0.00392156862745098, 0.5],
#  [0.2, 0.4, 0.00784313725490196, 0.5],
#  [0.2, 0.4, 0.011764705882352941, 0.5],
#  [0.2, 0.4, 0.01568627450980392, 0.5],
#  [0.2, 0.4, 0.0196078431372549, 0.5],
#  [0.2, 0.4, 0.023529411764705882, 0.5],
#  [0.2, 0.4, 0.027450980392156862, 0.5],
#  [0.2, 0.4, 0.03137254901960784, 0.5],
#  [0.2, 0.4, 0.03529411764705882, 0.5],
#  [0.2, 0.4, 0.0392156862745098, 0.5],
#  [0.2, 0.4, 0.043137254901960784, 0.5],
#  [0.2, 0.4, 0.047058823529411764, 0.5],
#  [0.2, 0.4, 0.050980392156862744, 0.5],
#  [0.2, 0.4, 0.054901960784313725, 0.5],
#  [0.2, 0.4, 0.058823529411764705, 0.5],
#  [0.2, 0.4, 0.06274509803921569, 0.5],
#  [0.2, 0.4, 0.06666666666666667, 0.5],
#  [0.2, 0.4, 0.07058823529411765, 0.5],
#  [0.2, 0.4, 0.07450980392156863, 0.5],
#  [0.2, 0.4, 0.0784313725490196, 0.5],
#  [0.2, 0.4, 0.08235294117647059, 0.5],
#  [0.2, 0.4, 0.08627450980392157, 0.5],
#  [0.2, 0.4, 0.09019607843137255, 0.5],
#  [0.2, 0.4, 0.09411764705882353, 0.5],
#  [0.2, 0.4, 0.09803921568627451, 0.5],
#  [0.2, 0.4, 0.10196078431372549, 0.5],
#  [0.2, 0.4, 0.10588235294117647, 0.5],
#  [0.2, 0.4, 0.10980392156862745, 0.5],
#  [0.2, 0.4, 0.11372549019607843, 0.5],
#  [0.2, 0.4, 0.11764705882352941, 0.5],
#  [0.2, 0.4, 0.12156862745098039, 0.5],
#  [0.2, 0.4, 0.12549019607843137, 0.5],
#  [0.2, 0.4, 0.12941176470588237, 0.5],
#  [0.2, 0.4, 0.13333333333333333, 0.5],
#  [0.2, 0.4, 0.13725490196078433, 0.5],
#  [0.2, 0.4, 0.1411764705882353, 0.5],
#  [0.2, 0.4, 0.1450980392156863, 0.5],
#  [0.2, 0.4, 0.14901960784313725, 0.5],
#  [0.2, 0.4, 0.15294117647058825, 0.5],
#  [0.2, 0.4, 0.1568627450980392, 0.5],
#  [0.2, 0.4, 0.1607843137254902, 0.5],
#  [0.2, 0.4, 0.16470588235294117, 0.5],
#  [0.2, 0.4, 0.16862745098039217, 0.5],
#  [0.2, 0.4, 0.17254901960784313, 0.5],
#  [0.2, 0.4, 0.17647058823529413, 0.5],
#  [0.2, 0.4, 0.1803921568627451, 0.5],
#  [0.2, 0.4, 0.1843137254901961, 0.5],
#  [0.2, 0.4, 0.18823529411764706, 0.5],
#  [0.2, 0.4, 0.19215686274509805, 0.5],
#  [0.2, 0.4, 0.19607843137254902, 0.5],
#  [0.2, 0.4, 0.2, 0.5],
#  [0.2, 0.4, 0.20392156862745098, 0.5],
#  [0.2, 0.4, 0.20784313725490197, 0.5],
#  [0.2, 0.4, 0.21176470588235294, 0.5],
#  [0.2, 0.4, 0.21568627450980393, 0.5],
#  [0.2, 0.4, 0.2196078431372549, 0.5],
#  [0.2, 0.4, 0.2235294117647059, 0.5],
#  [0.2, 0.4, 0.22745098039215686, 0.5],
#  [0.2, 0.4, 0.23137254901960785, 0.5],
#  [0.2, 0.4, 0.23529411764705882, 0.5],
#  [0.2, 0.4, 0.23921568627450981, 0.5],
#  [0.2, 0.4, 0.24313725490196078, 0.5],
#  [0.2, 0.4, 0.24705882352941178, 0.5],
#  [0.2, 0.4, 0.25098039215686274, 0.5],
#  [0.2, 0.4, 0.2549019607843137, 0.5],
#  [0.2, 0.4, 0.25882352941176473, 0.5],
#  [0.2, 0.4, 0.2627450980392157, 0.5],
#  [0.2, 0.4, 0.26666666666666666, 0.5],
#  [0.2, 0.4, 0.27058823529411763, 0.5],
#  [0.2, 0.4, 0.27450980392156865, 0.5],
#  [0.2, 0.4, 0.2784313725490196, 0.5],
#  [0.2, 0.4, 0.2823529411764706, 0.5],
#  [0.2, 0.4, 0.28627450980392155, 0.5],
#  [0.2, 0.4, 0.2901960784313726, 0.5],
#  [0.2, 0.4, 0.29411764705882354, 0.5],
#  [0.2, 0.4, 0.2980392156862745, 0.5],
#  [0.2, 0.4, 0.30196078431372547, 0.5],
#  [0.2, 0.4, 0.3058823529411765, 0.5],
#  [0.2, 0.4, 0.30980392156862746, 0.5],
#  [0.2, 0.4, 0.3137254901960784, 0.5],
#  [0.2, 0.4, 0.3176470588235294, 0.5],
#  [0.2, 0.4, 0.3215686274509804, 0.5],
#  [0.2, 0.4, 0.3254901960784314, 0.5],
#  [0.2, 0.4, 0.32941176470588235, 0.5],
#  [0.2, 0.4, 0.3333333333333333, 0.5],
#  [0.2, 0.4, 0.33725490196078434, 0.5],
#  [0.2, 0.4, 0.3411764705882353, 0.5],
#  [0.2, 0.4, 0.34509803921568627, 0.5],
#  [0.2, 0.4, 0.34901960784313724, 0.5],
#  [0.2, 0.4, 0.35294117647058826, 0.5],
#  [0.2, 0.4, 0.3568627450980392, 0.5],
#  [0.2, 0.4, 0.3607843137254902, 0.5],
#  [0.2, 0.4, 0.36470588235294116, 0.5],
#  [0.2, 0.4, 0.3686274509803922, 0.5],
#  [0.2, 0.4, 0.37254901960784315, 0.5],
#  [0.2, 0.4, 0.3764705882352941, 0.5],
#  [0.2, 0.4, 0.3803921568627451, 0.5],
#  [0.2, 0.4, 0.3843137254901961, 0.5],
#  [0.2, 0.4, 0.38823529411764707, 0.5],
#  [0.2, 0.4, 0.39215686274509803, 0.5],
#  [0.2, 0.4, 0.396078431372549, 0.5],
#  [0.2, 0.4, 0.4, 0.5],
#  [0.2, 0.4, 0.403921568627451, 0.5],
#  [0.2, 0.4, 0.40784313725490196, 0.5],
#  [0.2, 0.4, 0.4117647058823529, 0.5],
#  [0.2, 0.4, 0.41568627450980394, 0.5],
#  [0.2, 0.4, 0.4196078431372549, 0.5],
#  [0.2, 0.4, 0.4235294117647059, 0.5],
#  [0.2, 0.4, 0.42745098039215684, 0.5],
#  [0.2, 0.4, 0.43137254901960786, 0.5],
#  [0.2, 0.4, 0.43529411764705883, 0.5],
#  [0.2, 0.4, 0.4392156862745098, 0.5],
#  [0.2, 0.4, 0.44313725490196076, 0.5],
#  [0.2, 0.4, 0.4470588235294118, 0.5],
#  [0.2, 0.4, 0.45098039215686275, 0.5],
#  [0.2, 0.4, 0.4549019607843137, 0.5],
#  [0.2, 0.4, 0.4588235294117647, 0.5],
#  [0.2, 0.4, 0.4627450980392157, 0.5],
#  [0.2, 0.4, 0.4666666666666667, 0.5],
#  [0.2, 0.4, 0.47058823529411764, 0.5],
#  [0.2, 0.4, 0.4745098039215686, 0.5],
#  [0.2, 0.4, 0.47843137254901963, 0.5],
#  [0.2, 0.4, 0.4823529411764706, 0.5],
#  [0.2, 0.4, 0.48627450980392156, 0.5],
#  [0.2, 0.4, 0.49019607843137253, 0.5],
#  [0.2, 0.4, 0.49411764705882355, 0.5],
#  [0.2, 0.4, 0.4980392156862745, 0.5],
#  [0.2, 0.4, 0.5019607843137255, 0.5],
#  [0.2, 0.4, 0.5058823529411764, 0.5],
#  [0.2, 0.4, 0.5098039215686274, 0.5],
#  [0.2, 0.4, 0.5137254901960784, 0.5],
#  [0.2, 0.4, 0.5176470588235295, 0.5],
#  [0.2, 0.4, 0.5215686274509804, 0.5],
#  [0.2, 0.4, 0.5254901960784314, 0.5],
#  [0.2, 0.4, 0.5294117647058824, 0.5],
#  [0.2, 0.4, 0.5333333333333333, 0.5],
#  [0.2, 0.4, 0.5372549019607843, 0.5],
#  [0.2, 0.4, 0.5411764705882353, 0.5],
#  [0.2, 0.4, 0.5450980392156862, 0.5],
#  [0.2, 0.4, 0.5490196078431373, 0.5],
#  [0.2, 0.4, 0.5529411764705883, 0.5]]

# %%
plt.scatter(data['x'],data['y'],s=250,c= color_list)

# %% [markdown]
# ## Bar chart

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# %% [markdown]
# แบบย่อ

# %%
plt.bar(x - width/2, men_means, width, label='Men')
plt.bar(x + width/2, women_means, width, label='Women')
plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.legend();

# %%
fig,ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels);
ax.legend();

# %% [markdown]
# ## Histogram

# %%
x = [12,25,7,7,1,1,1,1,5,5,5,5]

# %%
plt.hist(x)
# Out:
# (array([4., 4., 2., 0., 1., 0., 0., 0., 0., 1.]),
#  array([ 1. ,  3.4,  5.8,  8.2, 10.6, 13. , 15.4, 17.8, 20.2, 22.6, 25. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist('a a a s d f a s d f s a d f e w r w e f s d f'.split())
# Out:
# (array([5., 4., 0., 4., 0., 5., 2., 0., 2., 1.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <a list of 10 Patch objects>)
