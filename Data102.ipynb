# %% [markdown]
# <a href="https://colab.research.google.com/github/tonpiplaifa/KKU_data_mining/blob/master/Data102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os

# %%
import pandas as pd

# %%
base_path = '/content/drive/My Drive/DWDM_material'

# %%
data = pd.read_csv(os.path.join(base_path,'test.csv'))

# %%
data.head()
# Out:
#    Unnamed: 0        x        y
# 0           0  55.3846  97.1795
# 1           1  51.5385  96.0256
# 2           2  46.1538  94.4872
# 3           3  42.8205  91.4103
# 4           4  40.7692  88.3333

# %%
data.describe()
# Out:
#        Unnamed: 0           x           y
# count  142.000000  142.000000  142.000000
# mean    70.500000   54.263273   47.832253
# std     41.135953   16.765142   26.935403
# min      0.000000   22.307700    2.948700
# 25%     35.250000   44.102600   25.288450
# 50%     70.500000   53.333300   46.025600
# 75%    105.750000   64.743600   68.525675
# max    141.000000   98.205100   99.487200

# %% [markdown]
# ## Box plot

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(data['x'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f334a7356d8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f334a74c128>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f334a74cba8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f334a74c828>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f334a7359e8>,
#   <matplotlib.lines.Line2D at 0x7f334a735d68>]}

# %%
plt.boxplot(data['x'], vert=False, whis=1.2)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f613db9d550>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f613db9df60>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f613dbaba20>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f613dbab6a0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f613db9d860>,
#   <matplotlib.lines.Line2D at 0x7f613db9dbe0>]}

# %%
oput = plt.boxplot(data['x'], vert=False, whis=1.2)

# %%
oput['fliers'][0].get_xdata()
# Out:
# array([93.3333, 95.3846, 98.2051, 91.2821])

# %%
oput['whiskers'][0].get_xdata()
# Out:
# array([44.1026, 22.3077])

# %%
oput['whiskers'][1].get_xdata()
# Out:
# array([64.7436, 89.4872])

# %% [markdown]
# ## Scatter plot

# %%
plt.scatter(data['x'],data['y'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-51c641cf8f12> in <module>()
# ----> 1 plt.scatter(data['x'],data['y'])
#
# NameError: name 'plt' is not defined

# %%
plt.scatter(data['x'],data['y'],s=25)

# %%
plt.scatter(data['x'],data['y'],s=data['y'])

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='k')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='m')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='c')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='y')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='#5d5df2',marker = '*')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='#5d5df2',marker = '*',alpha = 0.4)
plt.scatter([66,42,55],[20,14,80],s=250,alpha=0.6)

# %% [markdown]
# ## HW4 วาดปีกกลับนอให้ไดโนเสาร์

# %%
plt.scatter(data['x'],data['y'],s=100 ,c='#5d5df2',marker = '*')
plt.scatter([31,29,26,24,23,23,23,23,23],[80,83,87,89,90,72,77,83,86],s=100,c='r',marker = '*')
plt.scatter([80,80,85,90,91,92,93,94,95,96,97,95,96,97,95,92,89,83,83,85],[63,69,80,44,48,53,57,60,63,66,69,80,77,73,80,79,80,75,78,80],s=100,c='r',marker = '*')
